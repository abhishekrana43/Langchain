# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ['OPENAI_API_KEY']=os.getenv("OPENAI_API_KEY")

## Langcsmith Tracking

os.environ['LANGCHAIN_API_KEY']=os.getenv("LANGCHAIN_API_KEY")
os.environ['LANGCHAIN_TRACING_V2']="True"
os.environ['LANGCHAIN_PROJECT']=os.getenv("LANGCHAIN_PROJECT")

# %%
from langchain_openai import ChatOpenAI
llm=ChatOpenAI(model="gpt-4o")
print(llm)
# Out:
# profile={'max_input_tokens': 16385, 'max_output_tokens': 4096, 'text_inputs': True, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': False, 'structured_output': False, 'image_url_inputs': False, 'pdf_inputs': False, 'pdf_tool_message': False, 'image_tool_message': False, 'tool_choice': True} client=<openai.resources.chat.completions.completions.Completions object at 0x000001B6F17DE6C0> async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x000001B693CE30E0> root_client=<openai.OpenAI object at 0x000001B691B8C9E0> root_async_client=<openai.AsyncOpenAI object at 0x000001B693A4F7D0> model_kwargs={} openai_api_key=SecretStr('**********') stream_usage=True

# %%
## Input and get response from llm
result=llm.invoke("What is generative AI?")
print(result)
# Out:
# content='Generative AI, also known as generative adversarial networks (GANs), is a type of artificial intelligence that can create new data or content, such as images, text, music, or videos, by learning from existing examples. It works by pitting two neural networks against each other - a generator that creates new content, and a discriminator that evaluates the content created by the generator and provides feedback. Through this process, generative AI can generate realistic and high-quality output that mimics human creativity.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 101, 'prompt_tokens': 13, 'total_tokens': 114, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-DCn6LGBz279byFysEu5dos9PHHCuj', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019c8fea-b677-75e2-8e66-233600a79990-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 13, 'output_tokens': 101, 'total_tokens': 114, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
